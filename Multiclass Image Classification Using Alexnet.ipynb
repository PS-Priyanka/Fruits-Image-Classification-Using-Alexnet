# %% [markdown]
# # Multiclass Image Classification Using Alexnet Architecture
#
# This code does image classification for 7 fruit categories = ['apple', 'cabbage', 'carrot', 'cucumber', 'eggplant', 'pear', 'zucchini']

# %%
#importing necessary libraries
import os
import cv2
from glob import glob
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Activation,GlobalAveragePooling2D, Dense, BatchNormalization, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD

# %%
#Setting Training dir paths
train_path = './Dataset/Dataset/Train/'

# %%
#Setting Test dir paths        
test_path = './Dataset/Dataset/Test/'

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Displaying the image
img = load_img(train_path + "Apple/r0_0.jpg", target_size=(227,227))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
#Printing the shape of the image array 
x = img_to_array(img)
print(x.shape)
# Out:
# (227, 227, 3)

# %%
#Visualizing more Images from each class
images = ['apple', 'cabbage', 'carrot', 'cucumber', 'eggplant', 'pear', 'zucchini']
fig = plt.figure(figsize =(10,5))
for i in range(len(images)):
    ax = fig.add_subplot(3,3,i+1,xticks=[],yticks=[])
    plt.title(images[i])
    plt.axis("off")
    ax.imshow(load_img(train_path + images[i] +"/r0_0.jpg", target_size=(227,227)))

# %%
#Getting the count of images for each class
image_count = []
class_names = []
print('{:18s}'.format('class'), end='')
print('Count:')
print('-' * 24)
#Reading the image from each folder from training path
for folder in os.listdir(train_path):
    folder_num = len(os.listdir(os.path.join(train_path,folder)))
    image_count.append(folder_num)
    class_names.append(folder)
    print('{:20s}'.format(folder), end=' ')
    print(folder_num)
print('-' * 24)    
print("Number of classes : ",len(class_names))
# Out:
# class             Count:
# ------------------------
# apple                309
# cabbage              96
# carrot               101
# cucumber             100
# eggplant             160
# pear                 326
# zucchini             160
# ------------------------
# Number of classes :  7

# %%
#Plotting the count of images for each class
sns.set(rc={'figure.figsize':(5,5)})
sns.barplot(x=class_names, y=image_count)
plt.ylabel('Number of images in each class')
plt.show()

# %%
#Finding number of classes
className = glob(train_path + '/*')
num_classes = len(className)
print(num_classes)
# Out:
# 7

# %% [markdown]
# # Model using Alexnet architecture
#
# This model consist of 5 convolution layers followed by 3 fully connected layers. Ativation function used is relu. The network consists of a kernel or filters with size 11 x 11, 5 x 5, 3 x 3, 3 x 3 and 3 x 3 for its five convolutional layers respectively.

# %%
#Using Alexnet architecture. input is 227, 227,3 image and output is 7 classes of fruits 
model = tf.keras.models.Sequential([
    #1st Convolutional Layer
    tf.keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(227,227,3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    #2nd Convolutional Layer
    tf.keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    #3rd Convolutional Layer
    tf.keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    #4th Convolutional Layer
    tf.keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    #5th Convolutional Layer
    tf.keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    #Passing it to a Fully Connected layer
    tf.keras.layers.Flatten(),
    # 1st Fully Connected Layer
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),# Add Dropout to prevent overfitting
    # 2nd Fully Connected Layer
    tf.keras.layers.Dense(4096, activation='relu'),
    #tf.keras.layers.BatchNormalization(),
    #tf.keras.layers.Dropout(0.5),
    # 3rd Fully Connected Layer
    tf.keras.layers.Dense(1000, activation='relu'),
    #tf.keras.layers.BatchNormalization(),
    #tf.keras.layers.Dropout(0.5),
    #Output Layer
    tf.keras.layers.Dense(7, activation='softmax'),
    #tf.keras.layers.BatchNormalization()
])

# %%
# plot graph
plot_model(model, to_file='fruit_classification.png')

# %% [markdown]
# # Compiling the model

# %%
model.compile(
    optimizer=tf.optimizers.SGD(learning_rate=0.00001),
    loss='categorical_crossentropy',
    metrics=["accuracy"]
)

# %%
#Getting model's summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 55, 55, 96)        34944
#
#  batch_normalization (BatchN  (None, 55, 55, 96)       384
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 27, 27, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 27, 27, 256)       614656
#
#  batch_normalization_1 (Batc  (None, 27, 27, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 384)       885120
#
#  batch_normalization_2 (Batc  (None, 13, 13, 384)      1536
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 384)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 384)         1327488
#
#  batch_normalization_3 (Batc  (None, 6, 6, 384)        1536
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 256)         884992
#
#  batch_normalization_4 (Batc  (None, 6, 6, 256)        1024
#  hNormalization)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 4096)              37752832
#
#  batch_normalization_5 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 1000)              4097000
#
#  dense_3 (Dense)             (None, 7)                 7007
#
# =================================================================
# Total params: 62,407,239
# Trainable params: 62,396,295
# Non-trainable params: 10,944
# _________________________________________________________________

# %%
#Specifing epochs & batch size
epochs = 40
batch_size = 16
image_height = 227
image_width = 227

# %% [markdown]
# # Image Augmentation

# %%
#Creating an object of ImageDataGenerator for augmenting training dataset
train_datagen = ImageDataGenerator(rescale= 1./255,
rotation_range=10,
width_shift_range=0.1,
height_shift_range=0.1,
shear_range=0.1,
zoom_range=0.1,
horizontal_flip=True,
fill_mode='nearest')

#Creating an object of ImageDataGenerator for augmenting test dataset
test_datagen = ImageDataGenerator(rescale= 1./255)

# %%
#Generating batches of Augmented data of image size 227, 227 and batch size of 32
train_generator = train_datagen.flow_from_directory(
directory = train_path, 
target_size= (image_height, image_width), # resize to this size
batch_size = batch_size,
color_mode= "rgb",
class_mode= "categorical"
)

test_generator = test_datagen.flow_from_directory(
directory = test_path,
target_size=(image_height, image_width),
batch_size = batch_size,
color_mode= "rgb",
class_mode= "categorical")

nb_train_samples = train_generator.samples
nb_test_samples = test_generator.samples
classes = list(train_generator.class_indices.keys())
# Out:
# Found 1252 images belonging to 7 classes.
# Found 623 images belonging to 7 classes.

# %% [markdown]
# # Creating callback list

# %%
from keras.callbacks import ReduceLROnPlateau
#Callback to save the best model. Using checkpoint and earlystopping to monitor validation accuracy
callbacks_list = [
    tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy', factor=0.1, patience=10, verbose=1),
    tf.keras.callbacks.ModelCheckpoint(
        filepath='fruit_model.h5',
        monitor='val_accuracy', save_best_only=True, verbose=1),
    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10,verbose=1)
]

# %% [markdown]
# # Model Fit

# %%
#Fitting the model
#Training
history = model.fit(
        train_generator,
        steps_per_epoch=nb_train_samples // batch_size,
        epochs=epochs,
        callbacks = callbacks_list,
        validation_data=test_generator,
        verbose = 1,
        validation_steps=nb_test_samples // batch_size)
# Out:
# Epoch 1/40
# 78/78 [==============================] - ETA: 0s - loss: 2.1989 - accuracy: 0.1764
# Epoch 1: val_accuracy improved from -inf to 0.11349, saving model to fruit_model.h5
# 78/78 [==============================] - 19s 177ms/step - loss: 2.1989 - accuracy: 0.1764 - val_loss: 1.9795 - val_accuracy: 0.1135 - lr: 1.0000e-05
# Epoch 2/40
# 78/78 [==============================] - ETA: 0s - loss: 1.9656 - accuracy: 0.2508
# Epoch 2: val_accuracy improved from 0.11349 to 0.12336, saving model to fruit_model.h5
# 78/78 [==============================] - 12s 160ms/step - loss: 1.9656 - accuracy: 0.2508 - val_loss: 1.9957 - val_accuracy: 0.1234 - lr: 1.0000e-05
# Epoch 3/40
# 78/78 [==============================] - ETA: 0s - loss: 1.7863 - accuracy: 0.3293
# Epoch 3: val_accuracy did not improve from 0.12336
# 78/78 [==============================] - 12s 154ms/step - loss: 1.7863 - accuracy: 0.3293 - val_loss: 2.0926 - val_accuracy: 0.1184 - lr: 1.0000e-05
# Epoch 4/40
# 78/78 [==============================] - ETA: 0s - loss: 1.6015 - accuracy: 0.4070
# Epoch 4: val_accuracy did not improve from 0.12336
# 78/78 [==============================] - 12s 152ms/step - loss: 1.6015 - accuracy: 0.4070 - val_loss: 1.9983 - val_accuracy: 0.1118 - lr: 1.0000e-05
# Epoch 5/40
# 78/78 [==============================] - ETA: 0s - loss: 1.4571 - accuracy: 0.4636
# Epoch 5: val_accuracy improved from 0.12336 to 0.23355, saving model to fruit_model.h5
# 78/78 [==============================] - 12s 157ms/step - loss: 1.4571 - accuracy: 0.4636 - val_loss: 1.7531 - val_accuracy: 0.2336 - lr: 1.0000e-05
# Epoch 6/40
# 78/78 [==============================] - ETA: 0s - loss: 1.3409 - accuracy: 0.5129
# Epoch 6: val_accuracy improved from 0.23355 to 0.49836, saving model to fruit_model.h5
# 78/78 [==============================] - 12s 157ms/step - loss: 1.3409 - accuracy: 0.5129 - val_loss: 1.5482 - val_accuracy: 0.4984 - lr: 1.0000e-05
# Epoch 7/40
# 78/78 [==============================] - ETA: 0s - loss: 1.2241 - accuracy: 0.5817
# Epoch 7: val_accuracy improved from 0.49836 to 0.67434, saving model to fruit_model.h5
# 78/78 [==============================] - 12s 157ms/step - loss: 1.2241 - accuracy: 0.5817 - val_loss: 1.2081 - val_accuracy: 0.6743 - lr: 1.0000e-05
# Epoch 8/40
# 78/78 [==============================] - ETA: 0s - loss: 1.1761 - accuracy: 0.6157
# Epoch 8: val_accuracy improved from 0.67434 to 0.81414, saving model to fruit_model.h5
# 78/78 [==============================] - 12s 158ms/step - loss: 1.1761 - accuracy: 0.6157 - val_loss: 0.9225 - val_accuracy: 0.8141 - lr: 1.0000e-05
# Epoch 9/40
# 78/78 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.6570
# Epoch 9: val_accuracy improved from 0.81414 to 0.88158, saving model to fruit_model.h5
# 78/78 [==============================] - 13s 163ms/step - loss: 1.0951 - accuracy: 0.6570 - val_loss: 0.7770 - val_accuracy: 0.8816 - lr: 1.0000e-05
# Epoch 10/40
# 78/78 [==============================] - ETA: 0s - loss: 1.0333 - accuracy: 0.6877
# Epoch 10: val_accuracy improved from 0.88158 to 0.91941, saving model to fruit_model.h5
# 78/78 [==============================] - 12s 159ms/step - loss: 1.0333 - accuracy: 0.6877 - val_loss: 0.6777 - val_accuracy: 0.9194 - lr: 1.0000e-05
# Epoch 11/40
# 78/78 [==============================] - ETA: 0s - loss: 0.9585 - accuracy: 0.7079
# Epoch 11: val_accuracy did not improve from 0.91941
# 78/78 [==============================] - 12s 153ms/step - loss: 0.9585 - accuracy: 0.7079 - val_loss: 0.5931 - val_accuracy: 0.9128 - lr: 1.0000e-05
# Epoch 12/40
# 78/78 [==============================] - ETA: 0s - loss: 0.9195 - accuracy: 0.7168
# Epoch 12: val_accuracy did not improve from 0.91941
# 78/78 [==============================] - 12s 153ms/step - loss: 0.9195 - accuracy: 0.7168 - val_loss: 0.5712 - val_accuracy: 0.9128 - lr: 1.0000e-05
# Epoch 13/40
# 78/78 [==============================] - ETA: 0s - loss: 0.8876 - accuracy: 0.7395
# Epoch 13: val_accuracy improved from 0.91941 to 0.95230, saving model to fruit_model.h5
# 78/78 [==============================] - 12s 158ms/step - loss: 0.8876 - accuracy: 0.7395 - val_loss: 0.5290 - val_accuracy: 0.9523 - lr: 1.0000e-05
# Epoch 14/40
# 78/78 [==============================] - ETA: 0s - loss: 0.8504 - accuracy: 0.7686
# Epoch 14: val_accuracy improved from 0.95230 to 0.95395, saving model to fruit_model.h5
# 78/78 [==============================] - 12s 158ms/step - loss: 0.8504 - accuracy: 0.7686 - val_loss: 0.4829 - val_accuracy: 0.9539 - lr: 1.0000e-05
# Epoch 15/40
# 78/78 [==============================] - ETA: 0s - loss: 0.8007 - accuracy: 0.7807
# Epoch 15: val_accuracy did not improve from 0.95395
# 78/78 [==============================] - 12s 153ms/step - loss: 0.8007 - accuracy: 0.7807 - val_loss: 0.4167 - val_accuracy: 0.9474 - lr: 1.0000e-05
# Epoch 16/40
# 78/78 [==============================] - ETA: 0s - loss: 0.7369 - accuracy: 0.7989
# Epoch 16: val_accuracy did not improve from 0.95395
# 78/78 [==============================] - 12s 154ms/step - loss: 0.7369 - accuracy: 0.7989 - val_loss: 0.3969 - val_accuracy: 0.9474 - lr: 1.0000e-05
# Epoch 17/40
# 78/78 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.8155
# Epoch 17: val_accuracy improved from 0.95395 to 0.96053, saving model to fruit_model.h5
# 78/78 [==============================] - 12s 157ms/step - loss: 0.6930 - accuracy: 0.8155 - val_loss: 0.3638 - val_accuracy: 0.9605 - lr: 1.0000e-05
# Epoch 18/40
# 78/78 [==============================] - ETA: 0s - loss: 0.6981 - accuracy: 0.8252
# Epoch 18: val_accuracy did not improve from 0.96053
# 78/78 [==============================] - 12s 153ms/step - loss: 0.6981 - accuracy: 0.8252 - val_loss: 0.3338 - val_accuracy: 0.9572 - lr: 1.0000e-05
# Epoch 19/40
# 78/78 [==============================] - ETA: 0s - loss: 0.6619 - accuracy: 0.8422
# Epoch 19: val_accuracy did not improve from 0.96053
# 78/78 [==============================] - 15s 191ms/step - loss: 0.6619 - accuracy: 0.8422 - val_loss: 0.3472 - val_accuracy: 0.9326 - lr: 1.0000e-05
# Epoch 20/40
# 78/78 [==============================] - ETA: 0s - loss: 0.6436 - accuracy: 0.8398
# Epoch 20: val_accuracy improved from 0.96053 to 0.96546, saving model to fruit_model.h5
# 78/78 [==============================] - 15s 192ms/step - loss: 0.6436 - accuracy: 0.8398 - val_loss: 0.2932 - val_accuracy: 0.9655 - lr: 1.0000e-05
# Epoch 21/40
# 78/78 [==============================] - ETA: 0s - loss: 0.6364 - accuracy: 0.8301
# Epoch 21: val_accuracy improved from 0.96546 to 0.98849, saving model to fruit_model.h5
# 78/78 [==============================] - 14s 177ms/step - loss: 0.6364 - accuracy: 0.8301 - val_loss: 0.2848 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 22/40
# 78/78 [==============================] - ETA: 0s - loss: 0.5919 - accuracy: 0.8568
# Epoch 22: val_accuracy did not improve from 0.98849
# 78/78 [==============================] - 14s 174ms/step - loss: 0.5919 - accuracy: 0.8568 - val_loss: 0.2807 - val_accuracy: 0.9819 - lr: 1.0000e-05
# Epoch 23/40
# 78/78 [==============================] - ETA: 0s - loss: 0.5579 - accuracy: 0.8625
# Epoch 23: val_accuracy did not improve from 0.98849
# 78/78 [==============================] - 13s 170ms/step - loss: 0.5579 - accuracy: 0.8625 - val_loss: 0.2613 - val_accuracy: 0.9786 - lr: 1.0000e-05
# Epoch 24/40
# 78/78 [==============================] - ETA: 0s - loss: 0.5634 - accuracy: 0.8673
# Epoch 24: val_accuracy improved from 0.98849 to 0.99178, saving model to fruit_model.h5
# 78/78 [==============================] - 13s 167ms/step - loss: 0.5634 - accuracy: 0.8673 - val_loss: 0.2514 - val_accuracy: 0.9918 - lr: 1.0000e-05
# Epoch 25/40
# 78/78 [==============================] - ETA: 0s - loss: 0.5604 - accuracy: 0.8641
# Epoch 25: val_accuracy did not improve from 0.99178
# 78/78 [==============================] - 14s 174ms/step - loss: 0.5604 - accuracy: 0.8641 - val_loss: 0.2232 - val_accuracy: 0.9901 - lr: 1.0000e-05
# Epoch 26/40
# 78/78 [==============================] - ETA: 0s - loss: 0.5151 - accuracy: 0.8794
# Epoch 26: val_accuracy did not improve from 0.99178
# 78/78 [==============================] - 13s 167ms/step - loss: 0.5151 - accuracy: 0.8794 - val_loss: 0.2029 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 27/40
# 78/78 [==============================] - ETA: 0s - loss: 0.5098 - accuracy: 0.8827
# Epoch 27: val_accuracy did not improve from 0.99178
# 78/78 [==============================] - 12s 153ms/step - loss: 0.5098 - accuracy: 0.8827 - val_loss: 0.2179 - val_accuracy: 0.9638 - lr: 1.0000e-05
# Epoch 28/40
# 78/78 [==============================] - ETA: 0s - loss: 0.4821 - accuracy: 0.8940
# Epoch 28: val_accuracy did not improve from 0.99178
# 78/78 [==============================] - 12s 153ms/step - loss: 0.4821 - accuracy: 0.8940 - val_loss: 0.1968 - val_accuracy: 0.9918 - lr: 1.0000e-05
# Epoch 29/40
# 78/78 [==============================] - ETA: 0s - loss: 0.4652 - accuracy: 0.8989
# Epoch 29: val_accuracy did not improve from 0.99178
# 78/78 [==============================] - 12s 153ms/step - loss: 0.4652 - accuracy: 0.8989 - val_loss: 0.1901 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 30/40
# 78/78 [==============================] - ETA: 0s - loss: 0.4520 - accuracy: 0.9013
# Epoch 30: val_accuracy improved from 0.99178 to 0.99507, saving model to fruit_model.h5
# 78/78 [==============================] - 12s 157ms/step - loss: 0.4520 - accuracy: 0.9013 - val_loss: 0.1696 - val_accuracy: 0.9951 - lr: 1.0000e-05
# Epoch 31/40
# 78/78 [==============================] - ETA: 0s - loss: 0.4558 - accuracy: 0.8956
# Epoch 31: val_accuracy improved from 0.99507 to 0.99836, saving model to fruit_model.h5
# 78/78 [==============================] - 12s 157ms/step - loss: 0.4558 - accuracy: 0.8956 - val_loss: 0.1586 - val_accuracy: 0.9984 - lr: 1.0000e-05
# Epoch 32/40
# 78/78 [==============================] - ETA: 0s - loss: 0.4283 - accuracy: 0.9045
# Epoch 32: val_accuracy improved from 0.99836 to 1.00000, saving model to fruit_model.h5
# 78/78 [==============================] - 12s 157ms/step - loss: 0.4283 - accuracy: 0.9045 - val_loss: 0.1848 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 33/40
# 78/78 [==============================] - ETA: 0s - loss: 0.4334 - accuracy: 0.9053
# Epoch 33: val_accuracy did not improve from 1.00000
# 78/78 [==============================] - 12s 153ms/step - loss: 0.4334 - accuracy: 0.9053 - val_loss: 0.1508 - val_accuracy: 0.9984 - lr: 1.0000e-05
# Epoch 34/40
# 78/78 [==============================] - ETA: 0s - loss: 0.3954 - accuracy: 0.9110
# Epoch 34: val_accuracy did not improve from 1.00000
# 78/78 [==============================] - 12s 152ms/step - loss: 0.3954 - accuracy: 0.9110 - val_loss: 0.1432 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 35/40
# 78/78 [==============================] - ETA: 0s - loss: 0.4138 - accuracy: 0.9207
# Epoch 35: val_accuracy did not improve from 1.00000
# 78/78 [==============================] - 12s 153ms/step - loss: 0.4138 - accuracy: 0.9207 - val_loss: 0.1338 - val_accuracy: 0.9984 - lr: 1.0000e-05
# Epoch 36/40
# 78/78 [==============================] - ETA: 0s - loss: 0.3977 - accuracy: 0.9159
# Epoch 36: val_accuracy did not improve from 1.00000
# 78/78 [==============================] - 12s 154ms/step - loss: 0.3977 - accuracy: 0.9159 - val_loss: 0.1373 - val_accuracy: 0.9984 - lr: 1.0000e-05
# Epoch 37/40
# 78/78 [==============================] - ETA: 0s - loss: 0.3845 - accuracy: 0.9256
# Epoch 37: val_accuracy did not improve from 1.00000
# 78/78 [==============================] - 12s 154ms/step - loss: 0.3845 - accuracy: 0.9256 - val_loss: 0.1256 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 38/40
# 78/78 [==============================] - ETA: 0s - loss: 0.3668 - accuracy: 0.9401
# Epoch 38: val_accuracy did not improve from 1.00000
# 78/78 [==============================] - 12s 152ms/step - loss: 0.3668 - accuracy: 0.9401 - val_loss: 0.1268 - val_accuracy: 0.9984 - lr: 1.0000e-05
# Epoch 39/40
# 78/78 [==============================] - ETA: 0s - loss: 0.3728 - accuracy: 0.9231
# Epoch 39: val_accuracy did not improve from 1.00000
# 78/78 [==============================] - 12s 153ms/step - loss: 0.3728 - accuracy: 0.9231 - val_loss: 0.1076 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 40/40
# 78/78 [==============================] - ETA: 0s - loss: 0.3600 - accuracy: 0.9288
# Epoch 40: val_accuracy did not improve from 1.00000
# 78/78 [==============================] - 12s 152ms/step - loss: 0.3600 - accuracy: 0.9288 - val_loss: 0.1071 - val_accuracy: 0.9984 - lr: 1.0000e-05

# %% [markdown]
# # Accuracy and loss Learning curves

# %%
#plotting the loss function and accuracy for different epochs

plt.figure(1, figsize = (10, 10))  
plt.subplot(211)  
plt.plot(history.history['accuracy'])  
plt.plot(history.history['val_accuracy'])  
plt.title('Model Accuracy')  
plt.ylabel('Accuracy')  
plt.xlabel('Epoch')  
plt.legend(['train', 'validation'], loc='upper left')   

# plotting model loss 
plt.subplot(212)  
plt.plot(history.history['loss'])  
plt.plot(history.history['val_loss'])  
plt.title('Model Loss')  
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.legend(['train', 'validation'], loc='upper left')  
plt.show()

# %% [markdown]
# # Evaluating model

# %%
# model evaluation
score = model.evaluate(test_generator)
print('test loss:', score[0])
print('test accuracy:', score[1])
# Out:
# 39/39 [==============================] - 2s 52ms/step - loss: 0.1059 - accuracy: 0.9984
# test loss: 0.10594946146011353
# test accuracy: 0.9983948469161987

# %% [markdown]
# # Model Saving and Prediction

# %%
# save the whole model
model.save("./fruit_model.h5")

# %%
# make a prediction for a new image.

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model

# %%
sample_path='./Dataset/Dataset/new_samples/'
img = load_img(sample_path + "r0_6.jpg", target_size=(227,227))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
def load_image(filename):
    #load the image
    img = load_img(filename, grayscale=False, color_mode="rgb", target_size=(227, 227, 3))
    #convert to array
    img = img_to_array(img)
    #reshape into a single sample with 1 channel
    img = img.reshape(1, 227, 227, 3)
    #prepare pixel data
    img = img.astype('float32')
    img = img / 255.0
    return img

# %%
img = load_image(sample_path + "r0_2.jpg")
model = load_model('fruit_model.h5')

# %%
# predict the class
predict_x=model.predict(img)
result=np.argmax(predict_x,axis=1)
if result[0] == 0:
    print("Apple")
elif result[0] == 1:
    print("cabbage")
elif result[0] == 2:
    print("carrot")
elif result[0] == 3:
    print("cucumber")
elif result[0] == 4:
    print("eggplant")
elif result[0] == 5:
    print("pear")
elif result[0] == 6:
    print("zucchini")
else:
    print("Not in the list")
# Out:
# 1/1 [==============================] - 0s 112ms/step
# Apple

# %% [markdown]
# This classification model gives test accuracy of 80.73% and when tried on few sample images, it classifies them correctly.
